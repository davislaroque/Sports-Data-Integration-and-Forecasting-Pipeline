# %% [markdown]
# # Sports Betting Dashboard (EV Explorer)
# Use this notebook to fetch odds, de-vig probabilities, and visualize high-EV bets across NFL, NBA, and MLB.

# %%
import logging
from odds_utils import fetch_odds
from widgets_ui import build_dashboard

logging.getLogger().setLevel(logging.INFO)
build_dashboard(fetch_fn=fetch_odds)
